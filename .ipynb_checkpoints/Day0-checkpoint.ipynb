# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel("C:\\Python CA2\\DDW-2000C-08.xlsx")
df.shape
# Out:
# (2181, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2181 entries, 0 to 2180
# Data columns (total 45 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Unnamed: 0                                                                   2177 non-null   object
#  1   Unnamed: 1                                                                   2177 non-null   object
#  2   Unnamed: 2                                                                   2177 non-null   object
#  3   Unnamed: 3                                                                   2176 non-null   object
#  4   Unnamed: 4                                                                   2178 non-null   object
#  5   C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  2177 non-null   object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2         Unnamed: 3 Unnamed: 4  \
# count        2177       2177       2177               2176       2178
# unique          3          3         27                 26          6
# top         C2308         20        000  State - JHARKHAND      Rural
# freq         2175       2175         87                 87        725
#
#        C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# count                                                2177
# unique                                                 31
# top                                              All ages
# freq                                                   75
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 35  \
# count         2178        2177        2177        2178  ...         2177
# unique        2134        2105        2080        2000  ...          183
# top           1282         592         717          86  ...            0
# ...

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      Table      State     Distt.  Area Name     Total/
# 1       Name       Code       Code        NaN     Rural/
# 2        NaN        NaN        NaN        NaN     Urban/
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#   C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# 0                                          Age-group
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  1
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 35  \
# 0      Total        NaN        NaN  Illiterate  ...         NaN
# 1        NaN        NaN        NaN         NaN  ...         NaN
# 2        NaN        NaN        NaN         NaN  ...         NaN
# ...

# %%
df.isna().sum()
# Out:
# 0
# Table                3
# State                3
# Distt.               3
# Area Name            4
# Total/               2
# Age-group            3
# Total                2
# NaN                  2
# NaN                  2
# Illiterate           2
# NaN                  2
# NaN                  2
# Literate             2
# NaN                  2
# NaN                  2
# Educational level    0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Table                3
# State                3
# Distt.               3
# Area Name            4
# Total/               2
# Age-group            3
# Total                2
# NaN                  2
# NaN                  2
# Illiterate           2
# NaN                  2
# NaN                  2
# Literate             2
# NaN                  2
# NaN                  2
# Educational level    0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  1
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# NaN                  0
# NaN                  2
# NaN                  2
# ...
